# %%
# !usr/bin/python
# -*- encoding: utf-8 -*-
# Project: Deep - Recurrent Neural Network
# Author: Tracy Tao
# Date: 2022/04/13

# %% [markdown]
# - 循环神经网络中，我们首先需要确定如何添加**更多的层**， 以及在哪里添加**额外的非线性**
# ![image.png](attachment:03457b36-ec28-4c8c-a4e3-07f543140b4b.png)
# ![image.png](attachment:c580d3cf-05f3-415a-9115-f6e16902b6e5.png)

# %%
import torch
from torch import nn
from d2l import torch as d2l

# %%
batch_size, num_steps = 32, 35
train_iter, vocab = d2l.load_data_time_machine(batch_size, num_steps)
vocab_size, num_hiddens, num_layers = len(vocab), 256, 10
num_inputs = vocab_size
device = d2l.try_gpu()
lstm_layer = nn.LSTM(num_inputs, num_hiddens, num_layers) # 多了一个num_layer参数，设定深度lstm
model = d2l.RNNModel(lstm_layer, len(vocab))
model = model.to(device)

# %%
model
# Out:
# RNNModel(
#   (rnn): LSTM(28, 256, num_layers=10)
#   (linear): Linear(in_features=256, out_features=28, bias=True)
# )

# %%
gru_layer = nn.GRU(num_inputs, num_hiddens, num_layers)
model = d2l.RNNModel(gru_layer, len(vocab))
model
# Out:
# RNNModel(
#   (rnn): GRU(28, 256, num_layers=10)
#   (linear): Linear(in_features=256, out_features=28, bias=True)
# )
