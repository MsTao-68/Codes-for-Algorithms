# %%
# !usr/bin/python
# -*- encoding: utf-8 -*-
# Project: Bidirection Recurrent Neural Network
# Author: Tracy Tao
# Date: 2022/04/13

# %% [markdown]
# - 前向递归 forward recursion
# ![image.png](attachment:24d8c91a-1b83-413c-a449-8093d4a54ad0.png)
# - 后向递归 backward recursion
# ![image.png](attachment:fd6f100c-249e-488d-b267-e9a2be4828f0.png)
# ![image.png](attachment:ae4b4568-fa7f-46f0-a523-cd7500dcc474.png)
# ![image.png](attachment:46d63c5a-e3b4-4291-bb30-bf88ce16d9df.png)
# ![image.png](attachment:d90e7fa6-1941-473b-8815-120441695fd8.png)
# **由于双向循环神经网络使用了过去的和未来的数据， 所以我们不能盲目地将这一语言模型应用于任何预测任务。 尽管模型产出的困惑度是合理的， 该模型预测未来词元的能力却可能存在严重缺陷。**
# - 在双向循环神经网络中，每个时间步的隐状态由当前时间步的前后数据同时决定。
# - 由于梯度链更长，因此双向循环神经网络的训练代价非常高。

# %%
# 调包实现，lstm_layer = nn.LSTM(num_inputs, num_hiddens, num_layers, bidirectional=True)
